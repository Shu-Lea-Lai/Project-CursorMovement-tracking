# %%
using Distributions
using HMMBase
using PyPlot
using Seaborn

# %%
hmm = HMM([0.9 0.1; 0.1 0.9], [Normal(0,1), Normal(10,1)])
y = rand(hmm, 1000)

zv = viterbi(hmm, y)
# Out:
# [8.323476342282321, 10.297592285302972, 8.787401647473311, 6.6409861365385625, 9.52110099602183, 10.194887573966534, 10.391757909802664, 10.084935993600736, 11.495742580870736, 11.011229910050371, 11.116662119654539, 11.245055512161358, 8.731319004152287, 6.543878772655205, -0.7377832223607934, -0.07049922110262848, 0.893281776010457, -0.3970970855779608, 1.0954460852151708, 0.2575206740093126, -1.2176078448619412, 0.28507890066103886, -0.8547888987167239, 0.723395731926307, 1.0556997169608937, -0.7877768784186764, -0.31616891473583986, 0.11614643930777388, -0.5059144934148637, -0.42909334768540636, 1.5517160284851534, -0.026424918110467738, -0.3893335262814328, -0.8913240479709669, 0.35465531753964413, 1.0086875542174236, 0.35879361310532965, 0.4757668585590807, -0.895891119014391, 1.0024298410224655, -1.3768955023690272, 1.6010202976354149, 1.0733787496643348, -0.13131793351922977, -0.19512429598726533, 0.1678417763669622, -0.46126501501960926, 2.143782967530389, 0.9668282724970519
# ...

# %%
rand(hmm, 1000)
# Out:
# 1000-element Array{Float64,1}:
#  -0.7782977789931304
#   1.576090972302539
#   2.091271321574904
#  -0.27956490443984616
#   1.3006877504304277
#  -0.13547873918374162
#  -0.8884839435038341
#  -0.6533525751604253
#  -0.7911749257114318
#  -0.3461358360939972
#  -0.9630716370343521
#  -0.3029489682111855
#   1.0790114536248894
#   ⋮
#  -0.7315998478710659
#  -1.42199375446218
#   0.22958067964658394
#  -0.9109779260549158
#  -1.4845621537681724
#  -0.020811433737441702
#  10.820938497967001
#   9.301024148951685
#   9.50623339725089
#   9.902991019028894
#   8.114455206127369
#  11.96070187088071
